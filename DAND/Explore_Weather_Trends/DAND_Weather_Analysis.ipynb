# %%
import csv
with open('city_list.csv') as city_list:
    csv_reader = csv.reader(city_list)
    for row in csv_reader:
        print(row)
# Out:
# ['city', 'country']
# ['Abidjan', "C̫te D'Ivoire"]
# ['Abu Dhabi', 'United Arab Emirates']
# ['Abuja', 'Nigeria']
# ['Accra', 'Ghana']
# ['Adana', 'Turkey']
# ['Adelaide', 'Australia']
# ['Agra', 'India']
# ['Ahmadabad', 'India']
# ['Albuquerque', 'United States']
# ['Alexandria', 'Egypt']
# ['Alexandria', 'United States']
# ['Algiers', 'Algeria']
# ['Allahabad', 'India']
# ['Almaty', 'Kazakhstan']
# ['Amritsar', 'India']
# ['Amsterdam', 'Netherlands']
# ['Ankara', 'Turkey']
# ['Anshan', 'China']
# ['Antananarivo', 'Madagascar']
# ['Arlington', 'United States']
# ['Asmara', 'Eritrea']
# ['Astana', 'Kazakhstan']
# ['Athens', 'Greece']
# ['Atlanta', 'United States']
# ['Austin', 'United States']
# ['Baghdad', 'Iraq']
# ['Baku', 'Azerbaijan']
# ['Baltimore', 'United States']
# ['Bamako', 'Mali']
# ['Bandung', 'Indonesia']
# ['Bangalore', 'India']
# ['Bangkok', 'Thailand']
# ['Bangui', 'Central African Republic']
# ['Barcelona', 'Spain']
# ['Barcelona', 'Venezuela']
# ...

# %%
import pandas as pd
city_list = pd.read_csv('city_list.csv')
print(city_list.loc[city_list['country']=='India'])
# Out:
#           city country
# 6         Agra   India
# 7    Ahmadabad   India
# 12   Allahabad   India
# 14    Amritsar   India
# 30   Bangalore   India
# 44      Bhopal   India
# 85       Delhi   India
# 117      Haora   India
# 125  Hyderabad   India
# 129     Indore   India
# 135     Jaipur   India
# 145     Kanpur   India
# 182   Ludhiana   India
# 216     Nagpur   India
# 223  New Delhi   India
# 239      Patna   India
# 256       Pune   India
# 261     Rajkot   India
# 263     Ranchi   India
# 299      Surat   India
# 322   Vadodara   India
# 325   Varanasi   India

# %%
city_data=pd.read_csv("city_data.csv")
city_data.loc[city_data['city']=='Bangalore'].tail()
# Out:
#       year       city country  avg_temp
# 6580  2009  Bangalore   India     25.73
# 6581  2010  Bangalore   India     25.71
# 6582  2011  Bangalore   India     25.36
# 6583  2012  Bangalore   India     26.04
# 6584  2013  Bangalore   India     26.61

# %%
glob_data=pd.read_csv("global_data.csv")
glob_data.head()
# Out:
#    year  avg_temp
# 0  1750      8.72
# 1  1751      7.98
# 2  1752      5.78
# 3  1753      8.39
# 4  1754      8.47
